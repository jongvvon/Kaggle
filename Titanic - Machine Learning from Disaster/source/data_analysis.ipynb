# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/driver/MyDrive/Colab Notebooks/github/Kaggle/TItanic - Machine Learning from Disaster/data'

# %%
cd /content/drive/MyDrive/Colab Notebooks/github/Kaggle/Titanic - Machine Learning from Disaster/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/github/Kaggle/Titanic - Machine Learning from Disaster/data

# %%
# !ls -al
# Out:
# total 92
# -rw------- 1 root root  3258 Dec 10  2019 gender_submission.csv
# -rw------- 1 root root 28629 Dec 10  2019 test.csv
# -rw------- 1 root root 61194 Dec 10  2019 train.csv

# %%
import pandas as pd
import numpy as np
